# %%
import pandas as pd
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
import datetime as dt

# %%
#to read the dataset stored in the form of csv
sp=pd.read_csv('/content/weatherHistory.csv')
df=pd.DataFrame(sp)
print(df)
plt.style.use('ggplot')
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 6212  2006-05-23 21:00:00.000 +0200  Mostly Cloudy        rain
# 6213  2006-05-23 22:00:00.000 +0200  Mostly Cloudy        rain
# 6214  2006-05-23 23:00:00.000 +0200  Mostly Cloudy        rain
# 6215  2006-05-24 00:00:00.000 +0200  Partly Cloudy        rain
# 6216  2006-05-24 01:00:00.000 +0200  Partly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6217 entries, 0 to 6216
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            6217 non-null   object
#  1   Summary                   6217 non-null   object
#  2   Precip Type               6217 non-null   object
#  3   Temperature (C)           6217 non-null   float64
#  4   Apparent Temperature (C)  6217 non-null   float64
#  5   Humidity                  6217 non-null   float64
#  6   Wind Speed (km/h)         6217 non-null   float64
#  7   Wind Bearing (degrees)    6217 non-null   float64
#  8   Visibility (km)           6217 non-null   float64
#  9   Loud Cover                6216 non-null   float64
#  10  Pressure (millibars)      6216 non-null   float64
#  11  Daily Summary             6216 non-null   object
# dtypes: float64(8), object(4)
# memory usage: 583.0+ KB

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df=df.rename(columns={'Formatted Date':'FormattedDate','Temperature (C)':'Temperature','Apparent Temperature (C)':'ApparentTemperature','Wind Speed (km/h)':'WindSpeed','Wind Bearing (degrees)':'WindBearing','Visibility (km)':'Visibility','Pressure (millibars)':'Pressure','Daily Summary':'DailySummary'})

# %%
df.columns
# Out:
# Index(['FormattedDate', 'Summary', 'Precip Type', 'Temperature',
#        'ApparentTemperature', 'Humidity', 'WindSpeed', 'WindBearing',
#        'Visibility', 'Loud Cover', 'Pressure', 'DailySummary'],
#       dtype='object')

# %%
from datetime import date

# %%
df['FormattedDate']=pd.to_datetime(df['FormattedDate'],utc=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6217 entries, 0 to 6216
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FormattedDate        6217 non-null   datetime64[ns, UTC]
#  1   Summary              6217 non-null   object
#  2   Precip Type          6217 non-null   object
#  3   Temperature          6217 non-null   float64
#  4   ApparentTemperature  6217 non-null   float64
#  5   Humidity             6217 non-null   float64
#  6   WindSpeed            6217 non-null   float64
#  7   WindBearing          6217 non-null   float64
#  8   Visibility           6217 non-null   float64
#  9   Loud Cover           6216 non-null   float64
#  10  Pressure             6216 non-null   float64
#  11  DailySummary         6216 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(8), object(3)
# memory usage: 583.0+ KB

# %%
df['DateOnly']=pd.to_datetime(df['FormattedDate']).dt.date

# %%
df['DateOnly'].head()
# Out:
# 0    2006-03-31
# 1    2006-03-31
# 2    2006-04-01
# 3    2006-04-01
# 4    2006-04-01
# Name: DateOnly, dtype: object

# %%
#To display the range of the dataframe
df.index
# Out:
# RangeIndex(start=0, stop=6217, step=1)

# %%
#dtypes returns the datatype of each column
df.dtypes
# Out:
# FormattedDate          datetime64[ns, UTC]
# Summary                             object
# Precip Type                         object
# Temperature                        float64
# ApparentTemperature                float64
# Humidity                           float64
# WindSpeed                          float64
# WindBearing                        float64
# Visibility                         float64
# Loud Cover                         float64
# Pressure                           float64
# DailySummary                        object
# DateOnly                            object
# dtype: object

# %%
df['Pressure'].unique()
# Out:
# array([1015.13, 1015.63, 1015.94, ..., 1012.35, 1012.14,     nan])

# %%
df.count()
# Out:
# FormattedDate          6217
# Summary                6217
# Precip Type            6217
# Temperature            6217
# ApparentTemperature    6217
# Humidity               6217
# WindSpeed              6217
# WindBearing            6217
# Visibility             6217
# Loud Cover             6216
# Pressure               6216
# DailySummary           6216
# DateOnly               6217
# dtype: int64

# %%
df['ApparentTemperature'].value_counts().head(10)
# Out:
#  17.222222    13
#  17.777778    12
#  17.733333    11
#  12.755556    11
#  22.200000    11
#  12.827778    11
#  15.000000    10
#  20.072222    10
# -1.111111     10
#  16.161111    10
# Name: ApparentTemperature, dtype: int64

# %%
#Find  all the unique  'WindSpeed' values
df['WindSpeed'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 19.3683,  1.1592,  0.7567])

# %%
#Show first five unique values found in the array of unique values
df['WindSpeed'].head().unique()
# Out:
# array([14.1197, 14.2646,  3.9284, 14.1036, 11.0446])

# %%
df=df.rename(columns={'Precip Type':'PrecipType'})

# %%
#Finding the types of data in column Precip Type
df['PrecipType'].unique()
# Out:
# array(['rain', 'snow'], dtype=object)

# %%
#Total no. of rows with PrecipType as rain
df.query('PrecipType=="rain"').count()
# Out:
# FormattedDate          4980
# Summary                4980
# PrecipType             4980
# Temperature            4980
# ApparentTemperature    4980
# Humidity               4980
# WindSpeed              4980
# WindBearing            4980
# Visibility             4980
# Loud Cover             4979
# Pressure               4979
# DailySummary           4979
# DateOnly               4980
# dtype: int64

# %%
#Finding specific windspeed
#displaying the data of the first five rows with the same speed
df[df['WindSpeed']==3.9284].head()
# Out:
#                FormattedDate        Summary PrecipType  Temperature  \
# 2  2006-04-01 00:00:00+00:00  Mostly Cloudy       rain     9.377778
# 23 2006-04-01 21:00:00+00:00  Mostly Cloudy       rain    10.200000
#
#     ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# 2              9.377778      0.89     3.9284        204.0     14.9569
# 23            10.200000      0.77     3.9284        152.0     14.9569
#
#     Loud Cover  Pressure                       DailySummary    DateOnly
# 2          0.0   1015.94  Partly cloudy throughout the day.  2006-04-01
# 23         0.0   1015.51  Partly cloudy throughout the day.  2006-04-01

# %%
#No. of rows with the same Wind Speed values
df[df['WindSpeed']==3.9284].count()
# Out:
# FormattedDate          2
# Summary                2
# PrecipType             2
# Temperature            2
# ApparentTemperature    2
# Humidity               2
# WindSpeed              2
# WindBearing            2
# Visibility             2
# Loud Cover             2
# Pressure               2
# DailySummary           2
# DateOnly               2
# dtype: int64

# %%
#Specifically displays the count
df['WindSpeed'].where(df['WindSpeed']==3.9284).count()
# Out:
# 2

# %%
#Shows False as the values are not null at those data entry points
df.isnull()
# Out:
#       FormattedDate  Summary  PrecipType  Temperature  ApparentTemperature  \
# 0             False    False       False        False                False
# 1             False    False       False        False                False
# 2             False    False       False        False                False
# 3             False    False       False        False                False
# 4             False    False       False        False                False
# ...             ...      ...         ...          ...                  ...
# 6212          False    False       False        False                False
# 6213          False    False       False        False                False
# 6214          False    False       False        False                False
# 6215          False    False       False        False                False
# 6216          False    False       False        False                False
#
# ...

# %%
#Displays sum of all the rows with entry points empty/null columnwise
df.isnull().sum()
# Out:
# FormattedDate          0
# Summary                0
# PrecipType             0
# Temperature            0
# ApparentTemperature    0
# Humidity               0
# WindSpeed              0
# WindBearing            0
# Visibility             0
# Loud Cover             1
# Pressure               1
# DailySummary           1
# DateOnly               0
# dtype: int64

# %%
#Shows True as the values are not null at those data entry point
df.notnull()
# Out:
#       FormattedDate  Summary  PrecipType  Temperature  ApparentTemperature  \
# 0              True     True        True         True                 True
# 1              True     True        True         True                 True
# 2              True     True        True         True                 True
# 3              True     True        True         True                 True
# 4              True     True        True         True                 True
# ...             ...      ...         ...          ...                  ...
# 6212           True     True        True         True                 True
# 6213           True     True        True         True                 True
# 6214           True     True        True         True                 True
# 6215           True     True        True         True                 True
# 6216           True     True        True         True                 True
#
# ...

# %%
#Displays the no. of rows with the values present in every data entry points columnwise
df.notnull().sum()
# Out:
# FormattedDate          6217
# Summary                6217
# PrecipType             6217
# Temperature            6217
# ApparentTemperature    6217
# Humidity               6217
# WindSpeed              6217
# WindBearing            6217
# Visibility             6217
# Loud Cover             6216
# Pressure               6216
# DailySummary           6216
# DateOnly               6217
# dtype: int64

# %%
df['DateOnly']
# Out:
# 0       2006-03-31
# 1       2006-03-31
# 2       2006-04-01
# 3       2006-04-01
# 4       2006-04-01
#            ...
# 6212    2006-05-23
# 6213    2006-05-23
# 6214    2006-05-23
# 6215    2006-05-23
# 6216    2006-05-23
# Name: DateOnly, Length: 6217, dtype: object

# %%
df.head()
# Out:
#               FormattedDate        Summary PrecipType  Temperature  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy       rain     9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy       rain     9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy       rain     9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy       rain     8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy       rain     8.755556
#
#    ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# 0             7.388889      0.89    14.1197        251.0     15.8263
# 1             7.227778      0.86    14.2646        259.0     15.8263
# 2             9.377778      0.89     3.9284        204.0     14.9569
# 3             5.944444      0.83    14.1036        269.0     15.8263
# 4             6.977778      0.83    11.0446        259.0     15.8263
#
#    Loud Cover  Pressure                       DailySummary    DateOnly
# 0         0.0   1015.13  Partly cloudy throughout the day.  2006-03-31
# ...

# %%
df['Visibility'].mean()
# Out:
# 9.566517966865048

# %%
df.dtypes
# Out:
# FormattedDate          datetime64[ns, UTC]
# Summary                             object
# PrecipType                          object
# Temperature                        float64
# ApparentTemperature                float64
# Humidity                           float64
# WindSpeed                          float64
# WindBearing                        float64
# Visibility                         float64
# Loud Cover                         float64
# Pressure                           float64
# DailySummary                        object
# DateOnly                            object
# dtype: object

# %%
df['Pressure'].std()
# Out:
# 142.656997987498

# %%
df['Humidity'].var()
# Out:
# 0.03003531222460771

# %%
df[df['Summary']=='Partly Cloudy']
# Out:
#                  FormattedDate        Summary PrecipType  Temperature  \
# 0    2006-03-31 22:00:00+00:00  Partly Cloudy       rain     9.472222
# 1    2006-03-31 23:00:00+00:00  Partly Cloudy       rain     9.355556
# 3    2006-04-01 01:00:00+00:00  Partly Cloudy       rain     8.288889
# 5    2006-04-01 03:00:00+00:00  Partly Cloudy       rain     9.222222
# 6    2006-04-01 04:00:00+00:00  Partly Cloudy       rain     7.733333
# ...                        ...            ...        ...          ...
# 6207 2006-05-23 14:00:00+00:00  Partly Cloudy       rain    30.944444
# 6208 2006-05-23 15:00:00+00:00  Partly Cloudy       rain    30.044444
# 6209 2006-05-23 16:00:00+00:00  Partly Cloudy       rain    28.811111
# 6215 2006-05-23 22:00:00+00:00  Partly Cloudy       rain    19.972222
# 6216 2006-05-23 23:00:00+00:00  Partly Cloudy       rain    18.911111
#
#       ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# ...

# %%
df[df['Summary']=='Partly Cloudy'].count()
# Out:
# FormattedDate          1888
# Summary                1888
# PrecipType             1888
# Temperature            1888
# ApparentTemperature    1888
# Humidity               1888
# WindSpeed              1888
# WindBearing            1888
# Visibility             1888
# Loud Cover             1887
# Pressure               1887
# DailySummary           1887
# DateOnly               1888
# dtype: int64

# %%
df.where(df['Summary']=='Partly Cloudy')
# Out:
#                  FormattedDate        Summary PrecipType  Temperature  \
# 0    2006-03-31 22:00:00+00:00  Partly Cloudy       rain     9.472222
# 1    2006-03-31 23:00:00+00:00  Partly Cloudy       rain     9.355556
# 2                          NaT            NaN        NaN          NaN
# 3    2006-04-01 01:00:00+00:00  Partly Cloudy       rain     8.288889
# 4                          NaT            NaN        NaN          NaN
# ...                        ...            ...        ...          ...
# 6212                       NaT            NaN        NaN          NaN
# 6213                       NaT            NaN        NaN          NaN
# 6214                       NaT            NaN        NaN          NaN
# 6215 2006-05-23 22:00:00+00:00  Partly Cloudy       rain    19.972222
# 6216 2006-05-23 23:00:00+00:00  Partly Cloudy       rain    18.911111
#
#       ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# ...

# %%
#Find all instances where windspeed is above a specific number and Visibility is above a certain number
df[(df['WindSpeed']>19) & (df['Visibility']<16)].head()
# Out:
#                FormattedDate        Summary PrecipType  Temperature  \
# 11 2006-04-01 09:00:00+00:00  Partly Cloudy       rain    17.144444
# 12 2006-04-01 10:00:00+00:00  Partly Cloudy       rain    17.800000
# 13 2006-04-01 11:00:00+00:00  Partly Cloudy       rain    17.333333
# 35 2006-04-10 09:00:00+00:00  Mostly Cloudy       rain    17.355556
# 36 2006-04-10 10:00:00+00:00  Mostly Cloudy       rain    19.005556
#
#     ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# 11            17.144444      0.54    19.7869        316.0     11.4471
# 12            17.800000      0.55    21.9443        281.0     11.2700
# 13            17.333333      0.51    20.6885        289.0     11.2700
# 35            17.355556      0.52    22.7815        169.0      9.9820
# 36            19.005556      0.46    23.8924        169.0      9.9820
#
#     Loud Cover  Pressure                       DailySummary    DateOnly
# ...

# %%
df.groupby(df['Summary']).mean()
# Out:
# <ipython-input-41-da303fa452e4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(df['Summary']).mean()
#                           Temperature  ApparentTemperature  Humidity  \
# Summary
# Breezy and Foggy            -1.999206            -9.675397  0.937143
# Breezy and Mostly Cloudy     7.761667             3.533333  0.711500
# Breezy and Overcast          5.186444             0.433556  0.722000
# Breezy and Partly Cloudy    11.526984             9.705556  0.678571
# Clear                        9.138708             7.891272  0.797448
# Foggy                        0.611169            -1.404369  0.954896
# Humid and Mostly Cloudy     20.428704            20.428704  0.851667
# Humid and Partly Cloudy     21.759259            21.759259  0.850000
# ...

# %%
df.groupby(df['Summary']).min()
# Out:
# <ipython-input-42-c5fecad77de4>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df.groupby(df['Summary']).min()
#                                      FormattedDate PrecipType  Temperature  \
# Summary
# Breezy and Foggy         2006-03-13 06:00:00+00:00       snow    -2.200000
# Breezy and Mostly Cloudy 2006-01-22 16:00:00+00:00       rain    -6.966667
# Breezy and Overcast      2006-01-19 08:00:00+00:00       rain   -11.533333
# Breezy and Partly Cloudy 2006-03-25 07:00:00+00:00       rain     3.866667
# Clear                    2006-01-08 00:00:00+00:00       rain   -14.088889
# Foggy                    2006-01-05 00:00:00+00:00       rain    -9.022222
# Humid and Mostly Cloudy  2006-06-29 14:00:00+00:00       rain    20.050000
# Humid and Partly Cloudy  2006-06-30 16:00:00+00:00       rain    21.227778
# ...

# %%
df.groupby(df['Summary']).max()
# Out:
# <ipython-input-43-23815de8fa47>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(df['Summary']).max()
#                                      FormattedDate PrecipType  Temperature  \
# Summary
# Breezy and Foggy         2006-03-13 15:00:00+00:00       snow    -1.077778
# Breezy and Mostly Cloudy 2006-08-31 14:00:00+00:00       snow    25.466667
# Breezy and Overcast      2006-12-18 22:00:00+00:00       snow    18.933333
# Breezy and Partly Cloudy 2006-08-20 22:00:00+00:00       rain    21.966667
# Clear                    2006-12-31 13:00:00+00:00       snow    32.794444
# Foggy                    2006-12-31 22:00:00+00:00       snow    16.250000
# Humid and Mostly Cloudy  2006-08-04 12:00:00+00:00       rain    21.194444
# Humid and Partly Cloudy  2006-07-02 14:00:00+00:00       rain    22.661111
# ...

# %%
df[df['Summary']=='Breezy and Foggy']
# Out:
#                  FormattedDate           Summary PrecipType  Temperature  \
# 5191 2006-03-13 06:00:00+00:00  Breezy and Foggy       snow    -2.172222
# 5192 2006-03-13 07:00:00+00:00  Breezy and Foggy       snow    -2.200000
# 5193 2006-03-13 08:00:00+00:00  Breezy and Foggy       snow    -2.177778
# 5194 2006-03-13 09:00:00+00:00  Breezy and Foggy       snow    -2.105556
# 5195 2006-03-13 10:00:00+00:00  Breezy and Foggy       snow    -2.155556
# 5196 2006-03-13 11:00:00+00:00  Breezy and Foggy       snow    -2.105556
# 5200 2006-03-13 15:00:00+00:00  Breezy and Foggy       snow    -1.077778
#
#       ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# 5191           -10.044444      0.90    37.4808         18.0      1.4651
# 5192           -10.138889      0.89    38.0765         20.0      0.3542
# 5193            -9.977778      0.96    36.6275         20.0      0.3542
# 5194            -9.688889      0.96    34.6633         10.0      0.9821
# ...

# %%
df[df['Summary'].str.contains('Breezy and Foggy')]
# Out:
#                  FormattedDate           Summary PrecipType  Temperature  \
# 5191 2006-03-13 06:00:00+00:00  Breezy and Foggy       snow    -2.172222
# 5192 2006-03-13 07:00:00+00:00  Breezy and Foggy       snow    -2.200000
# 5193 2006-03-13 08:00:00+00:00  Breezy and Foggy       snow    -2.177778
# 5194 2006-03-13 09:00:00+00:00  Breezy and Foggy       snow    -2.105556
# 5195 2006-03-13 10:00:00+00:00  Breezy and Foggy       snow    -2.155556
# 5196 2006-03-13 11:00:00+00:00  Breezy and Foggy       snow    -2.105556
# 5200 2006-03-13 15:00:00+00:00  Breezy and Foggy       snow    -1.077778
#
#       ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# 5191           -10.044444      0.90    37.4808         18.0      1.4651
# 5192           -10.138889      0.89    38.0765         20.0      0.3542
# 5193            -9.977778      0.96    36.6275         20.0      0.3542
# 5194            -9.688889      0.96    34.6633         10.0      0.9821
# ...

# %%
df[(df['Summary']=='Partly Cloudy')|(df['Visibility']>30)]
# Out:
#                  FormattedDate        Summary PrecipType  Temperature  \
# 0    2006-03-31 22:00:00+00:00  Partly Cloudy       rain     9.472222
# 1    2006-03-31 23:00:00+00:00  Partly Cloudy       rain     9.355556
# 3    2006-04-01 01:00:00+00:00  Partly Cloudy       rain     8.288889
# 5    2006-04-01 03:00:00+00:00  Partly Cloudy       rain     9.222222
# 6    2006-04-01 04:00:00+00:00  Partly Cloudy       rain     7.733333
# ...                        ...            ...        ...          ...
# 6207 2006-05-23 14:00:00+00:00  Partly Cloudy       rain    30.944444
# 6208 2006-05-23 15:00:00+00:00  Partly Cloudy       rain    30.044444
# 6209 2006-05-23 16:00:00+00:00  Partly Cloudy       rain    28.811111
# 6215 2006-05-23 22:00:00+00:00  Partly Cloudy       rain    19.972222
# 6216 2006-05-23 23:00:00+00:00  Partly Cloudy       rain    18.911111
#
#       ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# ...

# %%
ls=pd.DataFrame(df.groupby(df['DateOnly']).mean())
# Out:
# <ipython-input-96-7a48fe109233>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ls=pd.DataFrame(df.groupby(df['DateOnly']).mean())

# %%
ls.head(5)
# Out:
#             Temperature  ApparentTemperature  Humidity  WindSpeed  \
# DateOnly
# 2005-12-31     0.577778            -4.050000  0.890000  17.114300
# 2006-01-01     4.075000            -0.174537  0.817083  21.229192
# 2006-01-02     5.263194             1.808796  0.847083  17.824713
# 2006-01-03     2.340509             0.445370  0.897083   7.726658
# 2006-01-04     2.251852            -0.663194  0.906667  12.152817
#
#             WindBearing  Visibility  Loud Cover     Pressure
# DateOnly
# 2005-12-31   140.000000    9.982000         0.0  1016.660000
# 2006-01-01   142.750000   11.348487         0.0  1011.985000
# 2006-01-02   164.583333    8.492079         0.0  1010.384167
# 2006-01-03   252.541667    9.223958         0.0  1021.170833
# 2006-01-04    35.000000    8.352546         0.0   981.770833

# %%
pk=ls.head(30)
op=pd.DataFrame(pk)

# %%
df[((df['Summary']=='Partly Cloudy') & (df['Humidity']>0.6)) |(df['Visibility']>15)]
# Out:
#                  FormattedDate        Summary PrecipType  Temperature  \
# 0    2006-03-31 22:00:00+00:00  Partly Cloudy       rain     9.472222
# 1    2006-03-31 23:00:00+00:00  Partly Cloudy       rain     9.355556
# 3    2006-04-01 01:00:00+00:00  Partly Cloudy       rain     8.288889
# 4    2006-04-01 02:00:00+00:00  Mostly Cloudy       rain     8.755556
# 5    2006-04-01 03:00:00+00:00  Partly Cloudy       rain     9.222222
# ...                        ...            ...        ...          ...
# 6197 2006-05-23 04:00:00+00:00  Partly Cloudy       rain    16.072222
# 6198 2006-05-23 05:00:00+00:00  Partly Cloudy       rain    19.872222
# 6213 2006-05-23 20:00:00+00:00  Mostly Cloudy       rain    22.172222
# 6215 2006-05-23 22:00:00+00:00  Partly Cloudy       rain    19.972222
# 6216 2006-05-23 23:00:00+00:00  Partly Cloudy       rain    18.911111
#
#       ApparentTemperature  Humidity  WindSpeed  WindBearing  Visibility  \
# ...

# %%
df['WindSpeed'].head(30).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Pressure'].head(30).plot(kind='bar')
# Out:
# <Axes: >

# %%
pl=df['Pressure'].head(30).plot(kind='hist',bins=20,title='Wind Speed')
pl.set_xlabel('Row')
pl.set_ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
lm=df['Pressure'].plot(kind='kde',title='Pressure')
lm.set_xlabel('Rows')
# Out:
# Text(0.5, 0, 'Rows')

# %%
df.head(30).plot(kind='scatter',x='Pressure',y='WindSpeed')
plt.show()

# %%
sns.scatterplot(x='Pressure',y='WindSpeed',hue='DateOnly',data=op)
# Out:
# <Axes: xlabel='Pressure', ylabel='WindSpeed'>

# %%
sns.pairplot(op,vars=['Pressure','WindSpeed','Temperature'])
plt.show()

# %%
sns.heatmap(op,annot=True)
# Out:
# <Axes: ylabel='DateOnly'>
